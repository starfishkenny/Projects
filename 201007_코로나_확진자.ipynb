# %%
import sys
from bs4 import BeautifulSoup
import urllib.request
import requests
import json
import pandas as pd
import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt
import matplotlib.font_manager as fm
fname = fm.FontProperties(fname='malgun.ttf').get_name()
import sqlite3
from IPython.display import Image
mpl.rc('font',family=fname)
import matplotlib.gridspec as gridspec
from jupyterthemes import jtplot
jtplot.style()
# %matplotlib inline
import platform
platform.system()
# 운영체제별 한글 폰트 설정
if platform.system() == 'Darwin': # Mac 환경 폰트 설정
    plt.rc('font', family='AppleGothic')
elif platform.system() == 'Windows': # Windows 환경 폰트 설정
    plt.rc('font', family='Malgun Gothic')
plt.rc('axes', unicode_minus=False) # 마이너스 폰트 설정
# 글씨 선명하게 출력하는 설정
# %config InlineBackend.figure_format = 'retina'

# %%
corona = pd.read_csv('Time.csv')
corona
# Out:
#            date  time     test  negative  confirmed  released  deceased
# 0    2020-01-20    16        1         0          1         0         0
# 1    2020-01-21    16        1         0          1         0         0
# 2    2020-01-22    16        4         3          1         0         0
# 3    2020-01-23    16       22        21          1         0         0
# 4    2020-01-24    16       27        25          2         0         0
# ..          ...   ...      ...       ...        ...       ...       ...
# 158  2020-06-26     0  1232315   1200885      12602     11172       282
# 159  2020-06-27     0  1243780   1211261      12653     11317       282
# 160  2020-06-28     0  1251695   1219975      12715     11364       282
# 161  2020-06-29     0  1259954   1228698      12757     11429       282
# 162  2020-06-30     0  1273766   1240157      12800     11537       282
#
# [163 rows x 7 columns]

# %% [markdown]
# ### 현재 데이터는 누적 데이터 --> 일일 데이터로 바꿀 필요성이 있음

# %%
# 일일 확진자 수 구하기

daily_confirmed = []
for i in range(len(corona)-1):
    daily_confirmed.append(corona['confirmed'][i+1]-corona['confirmed'][i])
    
daily_confirmed.insert(0,1)

corona['daily_confirmed'] = daily_confirmed

# %%
# 일일 test

daily_test = []
for i in range(len(corona)-1):
    daily_test.append(corona['test'][i+1]-corona['test'][i])
    
daily_test.insert(0,1)

corona['daily_test'] = daily_test

# %%
# 일일 음성판정 수

daily_negative = []
for i in range(len(corona)-1):
    daily_negative.append(corona['negative'][i+1]-corona['negative'][i])
    
daily_negative.insert(0,0)

corona['daily_negative'] = daily_negative

# %%
# 일일 퇴원 환자 수

daily_released = []
for i in range(len(corona)-1):
    daily_released.append(corona['released'][i+1]-corona['released'][i])
    
daily_released.insert(0,0)

corona['daily_released'] = daily_released

# %%
# 일일 사망자

daily_confirmed = []
for i in range(len(corona)-1):
    daily_confirmed.append(corona['confirmed'][i+1]-corona['confirmed'][i])
    
daily_confirmed.insert(0,0)

corona['daily_confirmed'] = daily_confirmed

# %%
# 시간 데이터 형식 변환
corona['date'][0].replace('-','')
# Out:
# '20200120'

# %%
new_date = []
for i in range(len(corona)):
    new_date.append(corona['date'][i].replace('-',''))

# %%
corona['new_date'] = new_date

# %%
cols = corona.columns.tolist()
cols
# Out:
# ['date',
#  'time',
#  'test',
#  'negative',
#  'confirmed',
#  'released',
#  'deceased',
#  'daily_confirmed',
#  'daily_test',
#  'daily_negative',
#  'daily_released',
#  'new_date']

# %%
cols = cols[:-1]+cols[-1:]

# %%
corona = corona[cols]

# %%
corona
# Out:
#            date  time     test  negative  confirmed  released  deceased  \
# 0    2020-01-20    16        1         0          1         0         0
# 1    2020-01-21    16        1         0          1         0         0
# 2    2020-01-22    16        4         3          1         0         0
# 3    2020-01-23    16       22        21          1         0         0
# 4    2020-01-24    16       27        25          2         0         0
# ..          ...   ...      ...       ...        ...       ...       ...
# 158  2020-06-26     0  1232315   1200885      12602     11172       282
# 159  2020-06-27     0  1243780   1211261      12653     11317       282
# 160  2020-06-28     0  1251695   1219975      12715     11364       282
# 161  2020-06-29     0  1259954   1228698      12757     11429       282
# 162  2020-06-30     0  1273766   1240157      12800     11537       282
#
#      daily_confirmed  daily_test  daily_negative  daily_released  new_date
# 0                  0           1               0               0  20200120
# 1                  0           0               0               0  20200121
# 2                  0           3               3               0  20200122
# 3                  0          18              18               0  20200123
# 4                  1           5               4               0  20200124
# ..               ...         ...             ...             ...       ...
# 158               39       11837           11870             198  20200626
# 159               51       11465           10376             145  20200627
# 160               62        7915            8714              47  20200628
# 161               42        8259            8723              65  20200629
# 162               43       13812           11459             108  20200630
#
# [163 rows x 12 columns]

# %%
corona.drop(['date'],axis='columns',inplace=True)

# %%
corona
# Out:
#      time     test  negative  confirmed  released  deceased  daily_confirmed  \
# 0      16        1         0          1         0         0                0
# 1      16        1         0          1         0         0                0
# 2      16        4         3          1         0         0                0
# 3      16       22        21          1         0         0                0
# 4      16       27        25          2         0         0                1
# ..    ...      ...       ...        ...       ...       ...              ...
# 158     0  1232315   1200885      12602     11172       282               39
# 159     0  1243780   1211261      12653     11317       282               51
# 160     0  1251695   1219975      12715     11364       282               62
# 161     0  1259954   1228698      12757     11429       282               42
# 162     0  1273766   1240157      12800     11537       282               43
#
#      daily_test  daily_negative  daily_released  new_date
# 0             1               0               0  20200120
# 1             0               0               0  20200121
# 2             3               3               0  20200122
# 3            18              18               0  20200123
# 4             5               4               0  20200124
# ..          ...             ...             ...       ...
# 158       11837           11870             198  20200626
# 159       11465           10376             145  20200627
# 160        7915            8714              47  20200628
# 161        8259            8723              65  20200629
# 162       13812           11459             108  20200630
#
# [163 rows x 11 columns]

# %%
# csv로 저장
corona.to_csv('.../코로나확진자.csv',index=False)

# %%
# db에 추가하기 위해선 데이터 타입 변경 필요 (->int)

new_corona = new_corona.astype({"new_date":str,"daily_test":int,"daily_confirmed":int,"daily_negative":int,"daily_released":int})

# %% [markdown]
# ### 데이터베이스에 추가

# %%
dbname='KOSPI.db'
def addData_co(data):
    with sqlite3.connect(dbname) as conn:
        cur=conn.cursor()
        sql = 'insert into Corona_day \
        (CIDX,DATE,TEST,CONFIRMED,NEGATIVE,RELEASED) \
        values (?,?,?,?,?,?)'
        cur.execute(sql,data)
        conn.commit()
        cur.close()

# %%
def selData_co(whr=' where CIDX=0'):
    with sqlite3.connect(dbname) as conn:
        cur=conn.cursor()
        sql='select CIDX from Corona_day '+whr
        cur.execute(sql)
        rows=cur.fetchall()
        cur.close()
    return rows

# %%
for i in range(len(new_corona)):
    cidx=new_corona['new_date'][i]+'1'
    data=[cidx,new_corona["new_date"][i],new_corona["daily_test"][i],new_corona["daily_confirmed"][i],
          new_corona["daily_negative"][i],new_corona["daily_released"][i]]
    preData=selData_co(' where CIDX='+cidx)
    if(preData):
        print("중복데이터 입니다.",preData)
    else:
        addData_co(data)
